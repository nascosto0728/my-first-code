# %% [markdown]
# <a href="https://colab.research.google.com/github/nascosto0728/my-first-code/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
x = np.arange(20) # x軸的值
y = 3 * x + 1  # y軸的值

plt.title("practice") # 圖的標題
plt.xlabel("x axis") # x軸的名稱
plt.ylabel("y axis") # y軸的名稱
plt.plot(x,y) # 繪製x,y軸的圖
plt.show() # 顯現圖形
